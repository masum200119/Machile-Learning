# %%
print(5+6)
# Out:
# 11

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Diabetes Missing Data.csv')

# %%
df
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0        NaN            NaN  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0            NaN  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0        NaN            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...

# %%
df.isnull().sum()
# Out:
# Pregnant               0
# Glucose                5
# Diastolic_BP          35
# Skin_Fold            227
# Serum_Insulin        374
# BMI                   11
# Diabetes_Pedigree      0
# Age                    0
# Class                  0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Pregnant           768 non-null    int64
#  1   Glucose            763 non-null    float64
#  2   Diastolic_BP       733 non-null    float64
#  3   Skin_Fold          541 non-null    float64
#  4   Serum_Insulin      394 non-null    float64
#  5   BMI                757 non-null    float64
#  6   Diabetes_Pedigree  768 non-null    float64
#  7   Age                768 non-null    int64
#  8   Class              768 non-null    int64
# dtypes: float64(6), int64(3)
# memory usage: 54.1 KB

# %%
df['Glucose'].fillna(df['Glucose'].mean(),inplace=True)

# %%
df['Glucose']
# Out:
# 0      148.0
# 1       85.0
# 2      183.0
# 3       89.0
# 4      137.0
#        ...
# 763    101.0
# 764    122.0
# 765    121.0
# 766    126.0
# 767     93.0
# Name: Glucose, Length: 768, dtype: float64

# %%
df['Diastolic_BP'].fillna(df['Diastolic_BP'].mean(),inplace=True)

# %%
df['Diastolic_BP']
# Out:
# 0      72.0
# 1      66.0
# 2      64.0
# 3      66.0
# 4      40.0
#        ...
# 763    76.0
# 764    70.0
# 765    72.0
# 766    60.0
# 767    70.0
# Name: Diastolic_BP, Length: 768, dtype: float64

# %%
# Check the number of null values in the 'Diastolic_BP' column
null_count = df['Diastolic_BP'].isnull().sum()

print(f"Number of null values in 'Diastolic_BP': {null_count}")
# Out:
# Number of null values in 'Diastolic_BP': 0

# %%
x=df['Serum_Insulin'].mode()
x
# Out:
# 0    105.0
# Name: Serum_Insulin, dtype: float64

# %%
df['Serum_Insulin'].fillna(105.0,inplace=True)

# %%
df['Serum_Insulin'].isnull().sum()
# Out:
# 0

# %%
df['Skin_Fold'].fillna(df['Skin_Fold'].mean(),inplace=True)

# %%
df['BMI'].fillna(df['BMI'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Pregnant             0
# Glucose              0
# Diastolic_BP         0
# Skin_Fold            0
# Serum_Insulin        0
# BMI                  0
# Diabetes_Pedigree    0
# Age                  0
# Class                0
# dtype: int64

# %%
x=df.drop(columns='Class')

# %%
y=df['Class']

# %%
x
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0   35.00000          105.0  33.6
# 1           1     85.0          66.0   29.00000          105.0  26.6
# 2           8    183.0          64.0   29.15342          105.0  23.3
# 3           1     89.0          66.0   23.00000           94.0  28.1
# 4           0    137.0          40.0   35.00000          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0   48.00000          180.0  32.9
# 764         2    122.0          70.0   27.00000          105.0  36.8
# 765         5    121.0          72.0   23.00000          112.0  26.2
# 766         1    126.0          60.0   29.15342          105.0  30.1
# 767         1     93.0          70.0   31.00000          105.0  30.4
#
#      Diabetes_Pedigree  Age
# 0                0.627   50
# 1                0.351   31
# 2                0.672   32
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Class, Length: 768, dtype: int64

# %%
df
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0   35.00000          105.0  33.6
# 1           1     85.0          66.0   29.00000          105.0  26.6
# 2           8    183.0          64.0   29.15342          105.0  23.3
# 3           1     89.0          66.0   23.00000           94.0  28.1
# 4           0    137.0          40.0   35.00000          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0   48.00000          180.0  32.9
# 764         2    122.0          70.0   27.00000          105.0  36.8
# 765         5    121.0          72.0   23.00000          112.0  26.2
# 766         1    126.0          60.0   29.15342          105.0  30.1
# 767         1     93.0          70.0   31.00000          105.0  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.svm import SVC

# %%
from sklearn.linear_model import LogisticRegression

# %%
ba=DecisionTreeClassifier

# %%
b=SVC()

# %%
c=LogisticRegression()

# %%
xtrain
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 334         1     95.0     60.000000   18.00000           58.0  23.9
# 139         5    105.0     72.000000   29.00000          325.0  36.9
# 485         0    135.0     68.000000   42.00000          250.0  42.3
# 547         4    131.0     68.000000   21.00000          166.0  33.1
# 18          1    103.0     30.000000   38.00000           83.0  43.3
# ..        ...      ...           ...        ...            ...   ...
# 71          5    139.0     64.000000   35.00000          140.0  28.6
# 106         1     96.0    122.000000   29.15342          105.0  22.4
# 270        10    101.0     86.000000   37.00000          105.0  45.6
# 435         0    141.0     72.405184   29.15342          105.0  42.4
# 102         0    125.0     96.000000   29.15342          105.0  22.5
#
#      Diabetes_Pedigree  Age
# 334              0.260   22
# 139              0.159   28
# 485              0.365   24
# ...

# %%
ytrain
# Out:
# 334    0
# 139    0
# 485    1
# 547    0
# 18     0
#       ..
# 71     0
# 106    0
# 270    1
# 435    1
# 102    0
# Name: Class, Length: 537, dtype: int64

# %%
ba=DecisionTreeClassifier()

# %%
ba.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
ba.score(xtest,ytest)
# Out:
# 0.696969696969697

# %%
b.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
b.score(xtest,ytest)
# Out:
# 0.7402597402597403

# %%
c.fit(xtrain,ytrain)
# Out:
# C:\Users\MASUM\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
c.score(xtest,ytest)
# Out:
# 0.7445887445887446

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
ypred=c.predict(xtest)

# %%
cm=confusion_matrix(ytest,ypred)

# %%
cl=classification_report(ytest,ypred)

# %%
print(cl)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.81       151
#            1       0.64      0.60      0.62        80
#
#     accuracy                           0.74       231
#    macro avg       0.72      0.71      0.71       231
# weighted avg       0.74      0.74      0.74       231

# %%
cm
# Out:
# array([[124,  27],
#        [ 32,  48]], dtype=int64)

# %%
import seaborn as sns

# %%
sns.heatmap(cm, annot=True, fmt='d')
# Out:
# <Axes: >
